# %%
import pandas as pd

# %%
ds = pd.read_csv('./data/wdbc-train.csv')

# %%
ds.head()
# Out:
#    diagnosis  meanradius  meantexture  meanperimeter  meanarea  \
# 0          0   -1.150365    -0.390642      -1.128550 -0.958764
# 1          0   -0.937990     0.680514      -0.948201 -0.821525
# 2          0    0.574121    -1.033336       0.513941  0.408586
# 3          0   -0.547220    -0.316022      -0.577622 -0.566615
# 4          0   -0.527398     0.791240      -0.561563 -0.523571
#
#    meansmoothness  meancompactness  meanconcavity  meanconcavepoints  \
# 0        0.310984        -0.595995      -0.802596          -0.802490
# 1       -0.609636        -0.909867      -0.660669          -0.898716
# 2       -0.106161        -0.363019      -0.417990          -0.088446
# 3        0.586662        -0.649331      -0.805298          -0.500065
# 4       -1.051446        -1.017532      -0.905149          -0.935806
#
#    meansymmetry  ...  worstradius  worsttexture  worstperimeter  worstarea  \
# 0      0.294539  ...    -1.043176      0.213533       -1.036045  -0.848808
# ...
